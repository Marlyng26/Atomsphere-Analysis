# %% [markdown]
# <a href="https://colab.research.google.com/github/Marlyng26/Atomsphere-Analysis/blob/main/Handout_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In-class activity 3 Week #2
# ---

# %% [markdown]
# ## **Part 1**

# %% [markdown]
# We're going to spend some time using another practice dataset focused on a wine. This dataset is used for wine recognition (with ML) based on its variables.
#
# More information about the dataset can be found here: http://rasbt.github.io/mlxtend/user_guide/data/wine_data/

# %% [markdown]
# **Run the code below to load the dataframe:**

# %%
# import pandas as pd
import pandas as pd

# Import datasets submodule
from sklearn import datasets

# Load dataset (actual data with associated documentation)
wine = datasets.load_wine()

# Create dataframe
wine_df = pd.DataFrame(data=wine.data,columns=wine.feature_names)

# Add target to dataset
wine_df['target'] = wine.target_names[wine.target]

# %%
#If we type wine_df the data frame will show. If we type wine_df.head() the first 5 rows will show
#If we type wine_df.tail() we will get the last five rows of the data frame
wine_df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# #### **Explore the dataset by answering the following questions:**

# %% [markdown]
# #### **Problem #1:**
# How many variables are there?
# To get the varibles we can type the following code  wine_df.columns. When we type wine_df.columns we obtain the column names. We can count these to get number of variables.

# %%
 #Get the column names (variables)
wine_df.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'target'],
#       dtype='object')

# %% [markdown]
# ##### **Solution**

# %%
# 14
#if we want to get the number of columns we type wine_df.shape[1]. However, if we want the number of rows type wine_df.shape[0]
wine_df.shape[1]
# Out:
# 14

# %% [markdown]
# #### **Problem #2:**
#
# How many instances are there?

# %%
# As mentioned earlier to get the number of instances or rows we use the attribute .shape. In this case, wine_df.shape[0] provides
#us with the number of rows. It is important to remember a row in a DataFrame is an instance of a  row class, which
#holds the values for a particular record.

# %% [markdown]
# ##### **Solution**

# %%
# 178
wine_df.shape[0]
# Out:
# 178

# %% [markdown]
# #### **Problem #3:**
#
# What is the data type for `color_intensity`?
# When we use .dytpes attribute to find the type of data for 'color_intensity,
# we find that the data type is a float. A float64 is a data type in pandas that keeps decimal numbers with high precision.

# %% [markdown]
# ##### **Solution**

# %%
# float64
# This indicates the data type is decimals

wine_df["color_intensity"].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# #### **Problem #4:**
#
# What is the mean of `color_intensity`?
# To find the mean, we need to use the method .mean() on the column we are trying to find the mean for. In this case it is 'color_intensity. Therefore, the code would be wine_df["color_intensity"].mean(). If we want to save it as a variable to reduce the number times we have to write out the code, we can use color_intensity_mean = wine_df["color_intensity"].mean()

# %%
#find the mean of color_intensity
color_intensity_mean = wine_df["color_intensity"].mean()
print(color_intensity_mean)
# Out:
# 5.058089882022472

# %% [markdown]
# ##### **Solution**

# %%
print("mean: ", wine_df["color_intensity"].mean())
# Out:
# mean:  5.058089882022472

# %% [markdown]
# #### **Problem #5:**
#
# What is the median of `proline`? What is the mean?
# To find the median we use the method .median()
# To find the mean we use the method .mean()

# %%
#find the median of proline

proline_mean = wine_df["proline"].mean()
proline_median = wine_df["proline"].median()
print(proline_mean)
print(proline_median)
# Out:
# 746.8932584269663
# 673.5

# %% [markdown]
# ##### **Solution**

# %%
print("mean: ", wine_df["proline"].mean())
print("median: ", wine_df["proline"].median())
# Out:
# mean:  746.8932584269663
# median:  673.5

# %% [markdown]
# #### **Problem #6:**
#
# Exlpore the feature `alcohol`. Are there outliers? You can look at the column and use mean or median.
# In order of us to find the statistical summary of a dataframe, we need to use the method .describe(). The .describe() method will provide the mean, median, max, min, etc.

# %%
# .describe() returns the statistical summary of df
wine_df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %% [markdown]
# ##### **Solution**

# %%
# Show feature worst texture.
# When we put the brackets around the column name we obtain only the information for that column
# For this reason, if we want to obtain the mean, median, max and min of the only the column 'alcohol'
# we can single out that column by using []
print(wine_df['alcohol'])
#or use .describe()
# mean?
print("mean: ", wine_df['alcohol'].mean())
# median?
print("median: ", wine_df['alcohol'].median())
# max?
print("max: ", wine_df['alcohol'].max())
# min?
print("min: ", wine_df['alcohol'].min())
# Out:
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: alcohol, Length: 178, dtype: float64
# mean:  13.00061797752809
# median:  13.05
# max:  14.83
# min:  11.03

# %% [markdown]
# #### **Problem #7:**
# What is the `hue` for instance 99?
# In order to find the hue of instance 99, we need to use [] around the column hue to single out the column

# %%
hue_99 = wine_df['hue'][99]
print(hue_99)
# Out:
# 1.42

# %% [markdown]
# ##### **Solution**

# %%
wine_df['hue'][99]
# Out:
# 1.42

# %% [markdown]
# #### **Problem #8:**
#
# What is the value for `flavanoids` for instance 82?
# To get the value of flavanoides for instance 82, we need to single out the column "flavanoids" in the wine_df by using []. Next, we need to use [82] to return instance 82. Therefore, code would be wine_df["flavanoids"][82]. We can store this as a varaible by typing flavavoids_82 = wine_df["flavanoids"][82]

# %%
flavanoids_82 = wine_df["flavanoids"][82]
print(flavanoids_82)
# Out:
# 1.58

# %% [markdown]
# ##### **Solution**

# %%
wine_df['flavanoids'][82]
# Out:
# 1.58

# %% [markdown]
# #### **Problem #9:**
#
# What is the sum of `flavanoids`?
# the method .sum() will return the sum of flavanoids

# %%
sum_flavanoids = wine_df["flavanoids"].sum()
print(sum_flavanoids)
# Out:
# 361.21000000000004

# %% [markdown]
# ##### **Solution**

# %%
print("sum: ", wine_df['flavanoids'].sum())
# Out:
# sum:  361.21000000000004

# %% [markdown]
# #### **Problem #10:**
#
# What is the dtype of `target`?
#  To get the type of data target is in the wine_df, we need to use the code wine_df['target'].dtype. It should be noted that the attribute .dytpe will return the type of data a specified column is in a dataframe.

# %%
type_target = wine_df['target'].dtype
print(type_target)
# Out:
# object

# %% [markdown]
# ##### **Solution**

# %%
# 0?
wine_df["target"].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### **Problem #11:**
#
# What is the median and mean for `total_phenols`.
# .mean() and .median() will provide the mean and median for the specified column.

# %%
total_phenols_mean = wine_df["total_phenols"].mean()
total_phenols_median = wine_df["total_phenols"].median()
print(total_phenols_mean)
print(total_phenols_median)
# Out:
# 2.295112359550562
# 2.355

# %% [markdown]
# ##### **Solution**

# %%
print("mean: ", wine_df["total_phenols"].mean())
print("median: ", wine_df["total_phenols"].median())
# Out:
# mean:  2.295112359550562
# median:  2.355

# %% [markdown]
# #### **Problem #12:**
#
# Print rows 50 to 55.
#
#  .iloc is an attribute used to access rows and columns by integer location based on their numerical index. iloc means  "integer-location based indexing". With .iloc, we can access rows and columns by index. Also, we can slice data using integer indices.
# With .iloc, you can:

# %%
rows50_56 = wine_df.iloc[50:56]
print(rows50_56)
# Out:
#     alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 50    13.05        1.73  2.04               12.4       92.0           2.72
# 51    13.83        1.65  2.60               17.2       94.0           2.45
# 52    13.82        1.75  2.42               14.0      111.0           3.88
# 53    13.77        1.90  2.68               17.1      115.0           3.00
# 54    13.74        1.67  2.25               16.4      118.0           2.60
# 55    13.56        1.73  2.46               20.5      116.0           2.96
#
#     flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 50        3.27                  0.17             2.91             7.20  1.12
# 51        2.99                  0.22             2.29             5.60  1.24
# 52        3.74                  0.32             1.87             7.05  1.01
# 53        2.79                  0.39             1.68             6.30  1.13
# ...

# %% [markdown]
# ##### **Solution**

# %%
wine_df.iloc[50:56]
# Out:
#     alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 50    13.05        1.73  2.04               12.4       92.0           2.72
# 51    13.83        1.65  2.60               17.2       94.0           2.45
# 52    13.82        1.75  2.42               14.0      111.0           3.88
# 53    13.77        1.90  2.68               17.1      115.0           3.00
# 54    13.74        1.67  2.25               16.4      118.0           2.60
# 55    13.56        1.73  2.46               20.5      116.0           2.96
#
#     flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 50        3.27                  0.17             2.91             7.20  1.12
# 51        2.99                  0.22             2.29             5.60  1.24
# 52        3.74                  0.32             1.87             7.05  1.01
# 53        2.79                  0.39             1.68             6.30  1.13
# ...

# %% [markdown]
# #### **Problem #13:**
#
# What is the dtype of `magnesium`?
# the dtype of magnesium can be found using the attribute .dytpe

# %%
magnesium_dtype = wine_df["magnesium"].dtype
print(magnesium_dtype)
# Out:
# float64

# %% [markdown]
# ##### **Solution**

# %%
# float 64
wine_df["magnesium"].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ## **Part 2**

# %% [markdown]
# This dataset contains information about a doctor's patients that they saw on a given day. Use this dataframe to answer Problems #0-1.

# %%
patientID = [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111,
             112, 113, 114, 115]
weight = [125, 101, 165, 187, 144, 202, 113, 191, 223, 303,
          166, 150, 108, 217, 191]
gender = ['F', 'F', 'M', 'M', 'F', 'M', 'F',
          'M', 'M', 'F', 'F', 'M', 'F', 'M', 'M']
height = [64, 59, 70, 72, 66, 72, 61, 71, 74, 69, 69, 67,
          60, 70, 65]
age = [19, 28, 18, 32, 67, 49, 53, 32, 27, 23, 21, 42, 47, 37, 59]

df_dict = {"ID": patientID, "weight": weight,
           "gender": gender, "height (in)": height, "age": age}
patients_df = pd.DataFrame(df_dict)
patients_df
# Out:
#      ID  weight gender  height (in)  age
# 0   101     125      F           64   19
# 1   102     101      F           59   28
# 2   103     165      M           70   18
# 3   104     187      M           72   32
# 4   105     144      F           66   67
# 5   106     202      M           72   49
# 6   107     113      F           61   53
# 7   108     191      M           71   32
# 8   109     223      M           74   27
# 9   110     303      F           69   23
# 10  111     166      F           69   21
# 11  112     150      M           67   42
# 12  113     108      F           60   47
# 13  114     217      M           70   37
# 14  115     191      M           65   59

# %% [markdown]
# #### **Problem #1:**
#
# Print the average weight of the patients. Store this in a variable called `patients_mean`.
#
# To achieve this, we need to single out the column of weight and use the method .mean().

# %%
patients_mean = patients_df["weight"].mean()
print(patients_mean)
# Out:
# 172.4

# %% [markdown]
# ##### **Solution**

# %%
patients_mean = patients_df["weight"].mean()
print(patients_mean)
# Out:
# 172.4

# %% [markdown]
# #### **Problem #2:**
#
# Using the `.iloc` method, make a new dataframe that takes a slice of only the last 7 entries of the existing dataframe.
#
# To slice the data we need to use .iloc. Because we want to create a new dataframe with last seven of entries of original data, we need to go up to 8.
# Because indexing starts at 0, we need to go one number higher than the number of entries desired.

# %%
last_seven = patients_df.iloc[8:,:]
last_seven
# Out:
#      ID  weight gender  height (in)  age
# 8   109     223      M           74   27
# 9   110     303      F           69   23
# 10  111     166      F           69   21
# 11  112     150      M           67   42
# 12  113     108      F           60   47
# 13  114     217      M           70   37
# 14  115     191      M           65   59

# %% [markdown]
# ##### **Solution**

# %%
last_seven = patients_df.iloc[8:,:]
last_seven
# Out:
#      ID  weight gender  height (in)  age
# 8   109     223      M           74   27
# 9   110     303      F           69   23
# 10  111     166      F           69   21
# 11  112     150      M           67   42
# 12  113     108      F           60   47
# 13  114     217      M           70   37
# 14  115     191      M           65   59

# %% [markdown]
# #### **Problem #3:**
# You are performing preliminary data analysis for a vet's office. This datatset contains the names of the animals, their names, and their weights in lbs.
#
# Run the cell to load the dataframe and use the dataframe, `vet_df`, for Problems #4-5.

# %%
# RUN THIS CELL
vet_df = pd.DataFrame({"animal":["cat", "dog", "dog", "hamster", "dog", "cat", "dog"],
                       "name": ["Riley", "Charlie", "Tiny", "Pickle", "Benny", "Whiskers", "Jumbo"],
                       "weight_lbs": [12, 90, 25, 1, 45, 10, 115]})
vet_df
# Out:
#     animal      name  weight_lbs
# 0      cat     Riley          12
# 1      dog   Charlie          90
# 2      dog      Tiny          25
# 3  hamster    Pickle           1
# 4      dog     Benny          45
# 5      cat  Whiskers          10
# 6      dog     Jumbo         115

# %% [markdown]
# #### **Problem #4:**
# You want to tell your workers the average weight of animal they will be dealing with. Calculate that average and store it in `average_vet_weight`.
#
# To calculate and store the average_vet_weight, we need to single out the weight_lbs column in the vet dataframe by using the code vet_df["weight_lbs"] and to get the mean we need to add the method .mean(). We can store the mean as variable by assigning a name such as average_vet_weight

# %%
average_vet_weight = vet_df["weight_lbs"].mean()
print(average_vet_weight)
# Out:
# 42.57142857142857

# %% [markdown]
# ##### **Solution**

# %%
#obtain and print the average of vet weights
average_vet_weight = vet_df["weight_lbs"].mean()
print(average_vet_weight)
# Out:
# 42.57142857142857

# %% [markdown]
# #### **Problem #5:**
#
# Use the index location method (`.iloc`) to find the names of the pets, show it is the same as indexing via a column name.

# %% [markdown]
# ##### **Solution**

# %%
il = vet_df.iloc[:,1]

# %%
na = vet_df["name"]
il == na
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# Name: name, dtype: bool

# %%
print(na)
# Out:
# 0       Riley
# 1     Charlie
# 2        Tiny
# 3      Pickle
# 4       Benny
# 5    Whiskers
# 6       Jumbo
# Name: name, dtype: object

# %% [markdown]
# #### **Problem #6:**
#
# You are interested at looking at houses in Weston, MA. You want to come up with general statisitcs, so you look at some data from a house selling site. The data, `houses_df`, contains the location of each house as the town, state, and street. The associated statistics show the price and square footage of each house. Use the dataframe to answer Questions #7-9.

# %%
house_dict = {"town":["Weston", "Weston", "Weston", "Weston", "Weston", "Weston", "Weston", "Weston", "Weston"],
              "state": ["MA", "MA", "MA", "MA", "MA", "MA", "MA", "MA", "MA"],
              "street": ["Webster", "Perry", "Loring", "Wellsley", "Lantern", "Jericho", "Lexington", "Colchester", "Partridge"],
              "price": [10400000, 9750000, 2895000, 5100000, 1790000, 799000, 1995000, 4250000, 2195000],
              "feet": [14056, 12795, 5778, 12148, 4663, 1611, 4600, 6700, 4070]

}
houses_df = pd.DataFrame(house_dict)
houses_df
# Out:
#      town state      street     price   feet
# 0  Weston    MA     Webster  10400000  14056
# 1  Weston    MA       Perry   9750000  12795
# 2  Weston    MA      Loring   2895000   5778
# 3  Weston    MA    Wellsley   5100000  12148
# 4  Weston    MA     Lantern   1790000   4663
# 5  Weston    MA     Jericho    799000   1611
# 6  Weston    MA   Lexington   1995000   4600
# 7  Weston    MA  Colchester   4250000   6700
# 8  Weston    MA   Partridge   2195000   4070

# %% [markdown]
# #### **Problem #7:**
#
# Find the mean and median price and square feet of a house in Weston, MA.
# To find te mean and median of the houses price and sqaureft, we need to single out the columns ['price'] and ['feet'] from the house_df.

# %%
house_price_mean = houses_df['price'].mean()
house_price_median = houses_df['price'].median()
house_feet_mean = houses_df['feet'].mean()
house_feet_median = houses_df['feet'].median()

print(house_price_mean)
print(house_price_median)
print(house_feet_mean)
print(house_feet_median)
# Out:
# 4352666.666666667
# 2895000.0
# 7380.111111111111
# 5778.0

# %% [markdown]
# ##### **Solution**

# %%
print(f"Mean Price, {houses_df['price'].mean()}, Median Price {houses_df['price'].median()}")
print(f"Mean sqft, {houses_df['feet'].mean()}, Median sqft {houses_df['feet'].median()}")
# Out:
# Mean Price, 4352666.666666667, Median Price 2895000.0
# Mean sqft, 7380.111111111111, Median sqft 5778.0

# %% [markdown]
# #### **Problem #8:**
#
# Find the price of the 6th house.
# To find the price of the 6th house , we have to use .iloc to get the price of the 6th house we have to go to index 5 and column 4 because that is the column of the price.

# %%
house6_price = houses_df.iloc[5,3]
print(house6_price)
# Out:
# 799000

# %% [markdown]
# ##### **Solution**

# %%
houses_df.iloc[5,3]
# Out:
# 799000

# %% [markdown]
# #### **Problem #9:**
#
# Iterate through the dataframe and create a list of the mean price per square foot. Use this list to calculate the average price per square foot of a house in Weston, MA.
#
# To iterate through the dataframe, we need to creat a DataFrame with house prices and square footage. Next step is to calculate the price per square foot for each house. Then, we need to collect the price per square foot into a list.
# Laslty,  we need to calculate the average price per square foot by taking the mean of that list

# %%
price_per_sqft = []

for i in range(len(houses_df.iloc[:,1])):
  price_per_sqft.append(houses_df.iloc[i,3] / houses_df.iloc[i,4])

# %% [markdown]
# ##### **Solution**

# %%
price_per_sqft = []

for i in range(len(houses_df.iloc[:,1])):
  price_per_sqft.append(houses_df.iloc[i,3] / houses_df.iloc[i,4])

sum(price_per_sqft)/len(houses_df.iloc[:,1])
# Out:
# 545.5498790714108

# %% [markdown]
# In order to create a list we need [] and store the empty list to a name. Then we loop through using the for i in range.
